# %% [markdown]
# ## Indentation Examples
#
# This notebook enables the reproduction of the main results presented in the paper "Bioinspired spiking architecture enables energy constrained touch encoding" and is organized as follows:
#
# - Visulalization of input data;
# - Processing of the input data through both the considered SNN architectures under energy-constrained and unconstrained conditions;
# - Visualization of the neural dynamics and spiking activity of the SNN
# - Derivation of the instantaneous contact position.
#
# This notebook uses the same code emplyed to run the experiments described in the paper. To execute this code, ensure that the accompanying C++ code is properly compiled. Please refer to the provided documentation for detailed setup instructions.

# %%
import pickle
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps
from sympy import symbols, Eq, solve
from sympy import log as sym_log 
from subprocess import run

# plt.style.use('style.yml')              # comment this line if you don't have a Latex installation
sys.path.append('../')
import python_utils as utils


n_fbg = 21

# get arguments from the capsule application
path_args = '../../../args.txt'

with open(path_args, 'r') as file:
    args = file.readlines()
os.system('rm ' + path_args)

NETWORK_MODEL = args[0][:-1]
to_plot_ind = int(args[1][:-1])
variable_to_show = args[2]

# %%
print(f'Executing notebook with arguments: {NETWORK_MODEL}, {to_plot_ind}, {variable_to_show}')
# Out:
# Executing notebook with arguments: SC-BIO-EE, 4, V_membrane_pot

# %% [markdown]
# ### Importing data

# %%
with open('indentation_example/data.pkl', 'rb') as f:
    data = pickle.load(f)

X_ind = data['X_ind']
Y_ind = data['Y_ind']
Z_ind = data['Z_ind']


FBG_signal = data['FBG_signal']
force_signal = data['force_signal']

print('Number of samples:', len(X_ind))
# Out:
# Number of samples: 8

# %% [markdown]
# ### Visualization of the FBG signals

# %%
ind_dur_cs = len(FBG_signal[1][to_plot_ind])        # duration of the signal in cs
ind_dur_ms = 10*ind_dur_cs                          # duration of the signal in ms

fig = plt.figure(figsize=(11, 8))
for i_k, k in enumerate(FBG_signal.keys()):
    color = colormaps['tab20'](i_k) if i_k < 20 else 'black'
    plt.plot(np.arange(len(FBG_signal[k][to_plot_ind]))*10,1000*FBG_signal[k][to_plot_ind], label = k, color=color)

plt.ylabel('FBG signal [pm]')
plt.xlabel('time [ms]')
plt.legend(ncol=3)
plt.show()

# %% [markdown]
# Separation of the positive and negative components of the FBG signal and application of the non linear transformation

# %%
def log_transf(x, offset, p_in, p_out, lin_factor, b_var=-1):
    # (p_in, p_out):        p_out is the desidered output when x=p_in is passed
    # offset:               log_transf(x=0)
    # lin_factor:           if low the transformation is almost linear, if high is highly non-linear
    if lin_factor == 0.:
        return (offset + (p_out-offset)/p_in * x, 0)
    elif b_var<0:
        var_b = symbols('var_b')
        eq = Eq((lin_factor+1)*sym_log(1.+var_b*p_in) - var_b*p_in,0)
        sols = solve( eq )
        assert (0. in sols and len(sols)==2)
        b_var = float(f'{np.sort( np.array(sols) )[1]}')

    p_out = p_out - offset
    a = p_out/np.log(1+b_var*p_in)
    return (offset + a * np.log(1+b_var*x), b_var)

input_currs = np.zeros((2*n_fbg, ind_dur_cs))
p_in_pos = 0.384        # 99% quantile of positive signals  [see Table S1 in the Supplementary Material]
p_in_neg = 0.146        # 99% quantile of negative signals  [see Table S1 in the Supplementary Material]
offset   = 15
p_out = 50              # [pA] desidered output current when p_in_pos/neg are passed
lin_factor = 11

b_val_pos = log_transf(0, offset, p_in_pos, p_out, lin_factor)[1]
b_val_neg = log_transf(0, offset, p_in_neg, p_out, lin_factor)[1]

for i in range(n_fbg):
    signal = FBG_signal[i+1][to_plot_ind]
    signal_pos = np.where(signal>=0, signal, 0)
    signal_neg = np.where(signal<0, -signal, 0)
    input_currs[i]       = log_transf(signal_pos, offset, p_in_pos, p_out, lin_factor, b_val_pos)[0]
    input_currs[i+n_fbg] = log_transf(signal_neg, offset, p_in_neg, p_out, lin_factor, b_val_neg)[0]

# %% [markdown]
# Definition of some utility function to setup weights and baseline currents

# %%
def str_line(ind, v, reps):
    str_i = str(ind)
    str_v = "\t".join([ f'{j:.2f}' for j in v for i in range(reps) ])
    return "\t".join([ str_i, str_v ])

def setup_L1_currents(path_curr_files, path_biases, input_curr):
    offsets = np.loadtxt(path_biases)
    with open(path_curr_files, 'w') as f:
        for i_n in range(input_curr.shape[0]):
            inp = input_curr[i_n] + offsets[i_n]
            f.write( str_line(i_n, inp, 1)+'\n' )

tau_results = 100
def temp_update(t, dur, start):
    to_ret = np.linspace(0,dur-start-1, dur-start)
    to_ret = np.exp( -(to_ret-t)/tau_results )
    to_ret[:int(t)] = 0
    return 1/tau_results*np.array(to_ret)

# %% [markdown]
# ### Data processing through SNN

# %%
config_dir      = f'indentation_example/{NETWORK_MODEL}/config_files'
weight_bias_dir = f'indentation_example/{NETWORK_MODEL}/weights_currs'
L1_curr_dir     = f'indentation_example/{NETWORK_MODEL}/specific_Ies'
sim_dir         = f'indentation_example/{NETWORK_MODEL}/sim'

if not os.path.isdir(sim_dir):
    # run simulation
    setup_L1_currents(f'{L1_curr_dir}/sp_currL1.txt', f'{weight_bias_dir}/currL1.txt', input_currs)
    run(f'./main {config_dir}/sim.yaml', shell=True) #, stdout=f_out, stderr=f_err, text=True)
    os.system(f'mv {sim_dir} {sim_dir}_{to_plot_ind}')
# Out:
# Input sim file: indentation_example/SC-BIO-EE/config_files/sim.yaml
#
# SEED not fixed
# Simulation is going to start with the following parameters:
# t_end			7000
# dt			1
# input_mode		0
# n_step			10
# out_dir			indentation_example/SC-BIO-EE/sim
# subnets_config_yaml	indentation_example/SC-BIO-EE/config_files/config.yaml
# weights_config_yaml	indentation_example/SC-BIO-EE/config_files/config_weights.yaml
# connections_config_yaml	indentation_example/SC-BIO-EE/config_files/config_connections.yaml
# to_save_config_yaml	indentation_example/SC-BIO-EE/config_files/config_to_save.yaml
# training_config_yaml	none
# 	config files have been read and copied
# Network constructor called
# Eventual specific files for currents and weights have been copied
# L1 connected to
# 	L2 with 252 tot conn:	6 per source Neuron	42 per target neuron
# 	L3 with 43008 tot conn:	1024 per source Neuron	42 per target neuron
# L2 connected to
# 	L3 with 6144 tot conn:	1024 per source Neuron	6 per target neuron
# L3 connected to
# Network info:
# 	t_end 			7000
# 	n_step 			10
# 	dt (resolut)		1
# 	input mode		0
# 	subnets_config_yaml     indentation_example/SC-BIO-EE/sim/config.yaml
# 	weights_config_yaml     indentation_example/SC-BIO-EE/sim/config_weights.yaml
# 	connections_config_yaml indentation_example/SC-BIO-EE/sim/config_connections.yaml
# 	to_save_config_yaml     indentation_example/SC-BIO-EE/sim/config_to_save.yaml
# 	out_dir                 indentation_example/SC-BIO-EE/sim
# 	supported neuron models	aeif_cond_exp [2]   aeif_curr_exp [3]   aqif2_cond_exp [8]   aqif_cond_exp [4]   aqif_curr_exp [5]   iaf_cond_alpha [0]   iaf_cond_exp [6]   iaf_curr_alpha [1]   iaf_curr_exp [7]   parrot_neuron [9]
# 	subnets ordering
# 		[0] L1
# 		[1] L2
# 		[2] L3
# 		[4294967295] ext
# subnet info
# Subnetwork L1
# 	neuron_model		iaf_curr_exp
# 	id_model		7
# 	N			42
# 	C_m			40
# 	E_L			-70
# 	V_res			-70
# 	V_th			-50
# 	t_ref			2
# 	I_e			0
# 	specific_I_e_file	indentation_example/SC-BIO-EE/specific_Ies/sp_currL1.txt
# 	ext_in_rate		1
# 	dev_ext_weight		0
# 	tau_syn_ex		8
# 	tau_syn_in		4
# 	g_L			2
# 	V_peak			-50 (same as V_th)
# 	non_spec weights_ex FROM
# 	    ext		2
# 	non_spec weights_in FROM	empty
# 	spec weights FROM		empty
# 	delays_out TO
# 	    L2		2
# 	    L3		2
# 	conn prob TO (with specificity & trainability)
# 	    L2		1  spec    	non_train
# 		    out_weight_file: indentation_example/SC-BIO-EE/weights_currs/weights12.txt
# 	    L3		1  spec    	non_train
# 		    out_weight_file: indentation_example/SC-BIO-EE/weights_currs/weights13.txt
# 	to_save			0
# Subnetwork L2
# 	neuron_model		iaf_curr_exp
# 	id_model		7
# 	N			6
# 	C_m			40
# 	E_L			-70
# 	V_res			-70
# 	V_th			-50
# 	t_ref			2
# 	I_e			15
# 	specific_I_e_file	none
# 	ext_in_rate		1
# 	dev_ext_weight		0
# 	tau_syn_ex		8
# 	tau_syn_in		4
# 	g_L			2
# 	V_peak			-50 (same as V_th)
# 	non_spec weights_ex FROM
# 	    ext		2
# 	non_spec weights_in FROM	empty
# 	spec weights FROM
# 	    L1
# 	delays_out TO
# 	    L3		2
# 	conn prob TO (with specificity & trainability)
# 	    L3		1  spec    	non_train
# 		    out_weight_file: indentation_example/SC-BIO-EE/weights_currs/weights23.txt
# 	to_save			0
# Subnetwork L3
# 	neuron_model		iaf_curr_exp
# 	id_model		7
# 	N			1024
# 	C_m			40
# 	E_L			-70
# 	V_res			-70
# 	V_th			-50
# 	t_ref			2
# 	I_e			15
# 	specific_I_e_file	none
# 	ext_in_rate		1
# 	dev_ext_weight		0
# 	tau_syn_ex		8
# 	tau_syn_in		4
# 	g_L			2
# 	V_peak			-50 (same as V_th)
# 	non_spec weights_ex FROM
# 	    ext		2
# 	non_spec weights_in FROM	empty
# 	spec weights FROM
# 	    L1
# 	    L2
# 	delays_out TO
# 	conn prob TO (with specificity & trainability)
# 	to_save			0
# 0 %   t = 0
# 1 %   t = 70
# 2 %   t = 140
# 3 %   t = 210
# 4 %   t = 280
# 5 %   t = 350
# 6 %   t = 420
# 7 %   t = 490
# 8 %   t = 560
# 9 %   t = 630
# 10 %   t = 700
# 11 %   t = 770
# 12 %   t = 840
# 13 %   t = 910
# 14 %   t = 980
# 15 %   t = 1050
# 16 %   t = 1120
# 17 %   t = 1190
# 18 %   t = 1260
# 19 %   t = 1330
# 20 %   t = 1400
# 21 %   t = 1470
# 22 %   t = 1540
# 23 %   t = 1610
# 24 %   t = 1680
# 25 %   t = 1750
# 26 %   t = 1820
# 27 %   t = 1890
# 28 %   t = 1960
# 30 %   t = 2100
# 31 %   t = 2170
# 32 %   t = 2240
# 33 %   t = 2310
# 34 %   t = 2380
# 35 %   t = 2450
# 36 %   t = 2520
# 37 %   t = 2590
# 38 %   t = 2660
# 39 %   t = 2730
# 40 %   t = 2800
# 41 %   t = 2870
# 42 %   t = 2940
# 43 %   t = 3010
# 44 %   t = 3080
# 45 %   t = 3150
# 46 %   t = 3220
# 47 %   t = 3290
# 48 %   t = 3360
# 49 %   t = 3430
# 50 %   t = 3500
# 51 %   t = 3570
# 52 %   t = 3640
# 53 %   t = 3710
# 54 %   t = 3780
# 55 %   t = 3850
# 56 %   t = 3920
# 59 %   t = 4130
# 60 %   t = 4200
# 61 %   t = 4270
# 62 %   t = 4340
# 63 %   t = 4410
# 64 %   t = 4480
# 65 %   t = 4550
# 66 %   t = 4620
# 67 %   t = 4690
# 68 %   t = 4760
# 69 %   t = 4830
# 70 %   t = 4900
# 71 %   t = 4970
# 72 %   t = 5040
# 73 %   t = 5110
# 74 %   t = 5180
# 75 %   t = 5250
# 76 %   t = 5320
# 77 %   t = 5390
# 78 %   t = 5460
# 79 %   t = 5530
# 80 %   t = 5600
# 81 %   t = 5670
# 82 %   t = 5740
# 83 %   t = 5810
# 84 %   t = 5880
# 85 %   t = 5950
# 86 %   t = 6020
# 87 %   t = 6090
# 88 %   t = 6160
# 89 %   t = 6230
# 90 %   t = 6300
# 91 %   t = 6370
# 92 %   t = 6440
# 93 %   t = 6510
# 94 %   t = 6580
# 95 %   t = 6650
# 96 %   t = 6720
# 97 %   t = 6790
# 98 %   t = 6860
# 99 %   t = 6930
# evolution required 2.3798 s

# %% [markdown]
# ### Visualization of neuronal dynamics and spiking activity

# %%
''' some neurons hiddden states '''

variables_dict = {
    'V_membrane_pot': 0,
    'I_ex':           1,
    'I_in':           2
}


ls = [ 1,3 ] if 'SC-BIO' in NETWORK_MODEL else [ 1,2 ]
t = np.loadtxt(f'{sim_dir}_{to_plot_ind}/neuron_states/t.txt')

fig = plt.figure(figsize=(11, 8))

for i_l, l in enumerate(ls):
    data = np.loadtxt(f'{sim_dir}_{to_plot_ind}/neuron_states/L{l}_0.txt').T  
    plt.plot( data[variables_dict[variable_to_show]], label=f'L{l} neuron 0', color=f'C{i_l}' )

plt.ylabel(f'{variable_to_show} [{"pA" if variable_to_show in ["I_in", "I_ex"] else "mV"}]')
plt.xlabel('time [ms]')
plt.legend()
plt.show()

# %%
out_pop = 'L3' if 'SC-BIO' in NETWORK_MODEL else 'L2'
time_to_plot = 5040         # same as the one in the paper Figure 2 - panel c

sim = utils.SpikeSim(f'{sim_dir}_{to_plot_ind}', 'sim.yaml', neglect_t=0, neglect_t_end=-1, config_fname='config.yaml')

fig, axs = plt.subplots(1,2, figsize=(22, 8))
axs[0].eventplot(sim.data['L1'], linelengths=0.5)
axs[0].set_xlim(0, ind_dur_ms)
axs[0].set_xlabel('time [ms]')
axs[0].set_ylabel(f'L1 neuron ids')
axs[0].axvline(time_to_plot, color='gray', linestyle='-', linewidth=0.75)
axs[1].eventplot(sim.data[out_pop], linelengths=0.5)
axs[1].set_xlim(0, ind_dur_ms)
axs[1].set_xlabel('time [ms]')
axs[1].set_ylabel(f'{out_pop} neuron ids')
axs[1].axvline(time_to_plot, color='gray', linestyle='-', linewidth=0.75)
plt.show()

# %% [markdown]
# ### Visualization of the activity in the output layer and derivation of the instantaneous contact position.

# %%
order_LL = np.loadtxt( f'indentation_example/order_N.txt' ).astype(int)
Zs_LL = np.linspace( 2., 145., 32 )       # mm
Ts_LL = np.linspace( 0.15,3.,  32 )       # rad

T,Z = np.meshgrid(Ts_LL, Zs_LL)
T_shuff = T.flatten()[order_LL]
Z_shuff = Z.flatten()[order_LL]

fig = plt.figure(figsize=(11, 11))
activities = np.zeros((1024, ind_dur_ms))
out_spikes = sim.data[out_pop]
for neur in range(1024):
    for spike_t in out_spikes[neur]:
        activities[neur] += temp_update(spike_t, ind_dur_ms, 0) 
activities = activities*1000

# position of contact point
R_ind, T_ind, Z_ind_ = utils.cartesian_to_cilindric(X_ind[to_plot_ind], Y_ind[to_plot_ind], Z_ind[to_plot_ind])

# instantaneus estimate of the contact position
instant_activities = activities[:,time_to_plot]
instant_activities_thr = np.where(instant_activities>=np.quantile(instant_activities, 0.9), instant_activities, 0.)
prob = instant_activities_thr/np.sum(instant_activities_thr)
Z_inst = np.sum(prob*Z_shuff)
T_inst = np.sum(prob*T_shuff)

plt.scatter(T_shuff, Z_shuff, c=instant_activities, cmap='Blues', s=100)
cbar = plt.colorbar()
cbar.ax.set_ylabel('Instantaneous activity [Hz]')
plt.scatter(T_ind, Z_ind_, c='red', marker='*', s=200, label = 'contact point')
plt.scatter(T_inst, Z_inst, c='gold', marker='*', s=200, label = 'Inst. estimated position')
plt.xlabel(r'$\theta$ [rad]')
plt.ylabel(r'$z$ [mm]')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# NOTE: Please consider that the spiking activity of the network may vary from run to run due to the additive non-deterministic input noise. As detailed in the paper, the reported localization performance accounts for this noise.
